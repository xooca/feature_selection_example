# %%
import pandas as pd
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '2014.csv',
#  '2015.csv',
#  '2016.csv',
#  '2017.csv',
#  '2018.csv',
#  '2019.csv',
#  '2020.csv',
#  'Untitled.ipynb']

# %%
files = ['2014.csv','2015.csv','2016.csv','2017.csv','2018.csv','2019.csv','2020.csv']
ls_df=[]
for file in files:
    ls_df.append(pd.read_csv(file))

# %%
all_df = pd.concat(ls_df)

# %%
#all_df['postage']=all_df['postage'].str.strip().replace({'Rs':'', ',':''})
all_df['total']=all_df['total'].str.replace('[Rs\.]','|')

# %%
#float('Rs.3,670.00'.replace(' ','').replace('Rs.',' ').replace(',',' '))

# %%
all_df.head()
# Out:
#               order id                                              items  \
# 0  404-0044396-9977148        Wacom One Small (CTL 471/KO-C) Pen Tablet;
# 1  404-2578583-1133927  Defunct The Best Clear Screen Guard for Moto G...
# 2  404-2237489-1349938  Rainbow Clear Screen Guard/Protector for HP Sl...
# 3  404-0119327-7230716    Clublaptop Reversible 15.6 inch Laptop Sleeve;
# 4  404-5884963-7617903  HP Slate 7 VoiceTab Tablet (WiFi, 3G, Voice Ca...
#
#               to        date          total    postage gift  VAT  \
# 0  Prabhat Kumar  2014-10-28   ||| 3,670|00   Rs. 0.00  NaN  NaN
# 1  Prabhat Kumar  2014-06-29   ||| 1,198|00   Rs. 0.00  NaN  NaN
# 2  Prabhat Kumar  2014-06-29     ||| 299|00  Rs. 50.00  NaN  NaN
# 3  Prabhat Kumar  2014-06-29     ||| 225|00   Rs. 0.00  NaN  NaN
# 4  Prabhat Kumar  2014-06-29  ||| 13,498|00  Rs. 99.00  NaN  NaN
#
#           refund                                           payments invoice
# ...

# %%
all_df[all_df['invoice'].isnull()].iloc[50:]
# Out:
#                                order id                                 items  \
# 21                  403-9885189-4083547           Amazon Pay balance: Money;
# 23                  405-8374567-3761135           Amazon Pay balance: Money;
# 29                  405-0849896-6469143           Amazon Pay balance: Money;
# 30                  403-0134917-3149107           Amazon Pay balance: Money;
# 35                  405-9968401-5364364             Mobile Prepaid Recharge;
# ..                                  ...                                   ...
# 91                  D01-8631141-2392634          Chinta Chhodo Sukh Se Jiyo;
# 92                  D01-0801693-5714246                Content from Audible;
# 93                  D01-6980120-6927019  Share Market Guide (Hindi Edition);
# 95                  402-8783118-2893157                                   NaN
# 100  =SUBTOTAL(103, A2:A101) & " items"                                   NaN
#
# ...

# %%
all_df['invoice']
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#                              ...
# 96     https://www.amazon.in/gp/invoice/download.html...
# 97     https://www.amazon.in/gp/invoice/download.html...
# 98     https://www.amazon.in/gp/invoice/download.html...
# 99     https://www.amazon.in/gp/invoice/download.html...
# 100                                                  NaN
# Name: invoice, Length: 602, dtype: object
